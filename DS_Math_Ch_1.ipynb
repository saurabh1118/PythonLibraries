# %% [markdown]
# <a href="https://colab.research.google.com/github/saurabh1118/PythonLibraries/blob/main/DS_Math_Ch_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("income.csv" , names = ['name',"income"], skiprows=[0])
df
# Out:
#         name    income
# 0        Rob      5000
# 1      rafiq      6000
# 2       nina      4000
# 3      sofia      7500
# 4      mohan      8000
# 5        tao      7000
# 6  Elun musk  10000000

# %%
df.describe()
# Out:
#              income
# count  7.000000e+00
# mean   1.433929e+06
# std    3.777283e+06
# min    4.000000e+03
# 25%    5.500000e+03
# 50%    7.000000e+03
# 75%    7.750000e+03
# max    1.000000e+07

# %%
df.income.quantile(0.25 , interpolation='higher')
# Out:
# 6000

# %%
df.income.quantile(1)
# Out:
# 10000000.0

# %%
percentile_99 = df.income.quantile(0.99)
percentile_99
# Out:
# 9400479.999999994

# %%
df_no_outlier = df[df.income<=percentile_99]
df_no_outlier
# Out:
#     name  income
# 0    Rob    5000
# 1  rafiq    6000
# 2   nina    4000
# 3  sofia    7500
# 4  mohan    8000
# 5    tao    7000

# %%
df
# Out:
#         name    income
# 0        Rob      5000
# 1      rafiq      6000
# 2       nina      4000
# 3      sofia      7500
# 4      mohan      8000
# 5        tao      7000
# 6  Elun musk  10000000

# %%
df['income'][3] = np.NaN
# Out:
# <ipython-input-19-77870e44274a>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['income'][3] = np.NaN
# <ipython-input-19-77870e44274a>:1: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#         name      income
# 0        Rob      5000.0
# 1      rafiq      6000.0
# 2       nina      4000.0
# 3      sofia         NaN
# 4      mohan      8000.0
# 5        tao      7000.0
# 6  Elun musk  10000000.0

# %%
df.income.mean()
# Out:
# 1671666.6666666667

# %%
df_new = df.fillna(df.income.mean())
df_new
# Out:
#         name        income
# 0        Rob  5.000000e+03
# 1      rafiq  6.000000e+03
# 2       nina  4.000000e+03
# 3      sofia  1.671667e+06
# 4      mohan  8.000000e+03
# 5        tao  7.000000e+03
# 6  Elun musk  1.000000e+07

# %%
df_new = df.fillna(df.income.median())
df_new
# Out:
#         name      income
# 0        Rob      5000.0
# 1      rafiq      6000.0
# 2       nina      4000.0
# 3      sofia      6500.0
# 4      mohan      8000.0
# 5        tao      7000.0
# 6  Elun musk  10000000.0

# %%
#Practice Question

# %% [markdown]
# Use this air bnb new york city data set and remove outliers using percentile based on price per night for a given apartment/home. You can use suitable upper and lower limits on percentile based on your intuition. Your goal is to come up with new pandas dataframe that doesn't have the outliers present in it.

# %%
import pandas as pd

# %%
df = pd.read_csv("AB_NYC_2019.csv")
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
min_thresold, max_thresold = df.price.quantile([0.01,0.999])
min_thresold, max_thresold
# Out:
# (30.0, 3000.0)

# %%
df[df.price<min_thresold]
# Out:
#              id                                             name    host_id  \
# 957      375249                  Enjoy Staten Island Hospitality    1887999
# 2675    1428154              Central, Peaceful Semi-Private Room    5912572
# 2860    1620248    Large furnished 2 bedrooms- - 30 days Minimum    2196224
# 3020    1767037               Small Cozy Room Wifi & AC near JFK    9284163
# 3918    2431607                    Bright, Airy Room Share for 2    4973668
# ...         ...                                              ...        ...
# 48486  36280646                     Cable and wfi, L/G included.  272872092
# 48647  36354776    Cozy bedroom in diverse neighborhood near JFK  273393150
# 48832  36450814                         FLATBUSH HANG OUT AND GO  267223765
# 48867  36473044  The place you were dreaming for.(only for guys)  261338177
# 48868  36473253                     Heaven for you(only for guy)  261338177
#
# ...

# %%
df2 = df[(df.price>min_thresold)&(df.price<max_thresold)]
df2.shape
# Out:
# (48183, 16)

# %%
df2.sample(5)
# Out:
#              id                                             name    host_id  \
# 21438  17122054                     Charming Duplex in Manhattan  115057851
# 8365    6428913                           COBBLE HILL BROWNSTONE   13043852
# 22256  17944140  Cheap Cosy room w/desk quiet area 10mn from JFK  107455767
# 17938  14055238                Spacious Prospect Park Garden Apt   84303682
# 32488  25465008       Shared Apartment by Times Square Manhattan  187975743
#
#               host_name neighbourhood_group   neighbourhood  latitude  \
# 21438  Chito And Xavier           Manhattan     East Harlem  40.80999
# 8365             Claire            Brooklyn     Cobble Hill  40.68477
# 22256            Guelma              Queens        Rosedale  40.65377
# 17938  Brian And Rachel            Brooklyn      Park Slope  40.67003
# 32488           R.Henry           Manhattan  Hell's Kitchen  40.76488
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
df2.price.describe()
# Out:
# count    48183.000000
# mean       148.772036
# std        153.594795
# min         31.000000
# 25%         70.000000
# 50%        110.000000
# 75%        179.000000
# max       2999.000000
# Name: price, dtype: float64
